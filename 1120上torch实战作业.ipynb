# %%
import torch

# 定义sigmoid函数
def sigmoid(x):
    return 1 / (1 + torch.exp(-x))

# 创建变量x1和x2，并设置requires_grad=True
x1 = torch.tensor(0.0, requires_grad=True)
x2 = torch.tensor(1.0, requires_grad=True)

# 构建计算图
y = sigmoid(3 * sigmoid(x1**2 + 2*x2 + 1) + sigmoid(x1**2 + 2*x2 + 1) + 1)

# 计算梯度
y.backward()

# 打印梯度
print(f"Gradient of y with respect to x1: {x1.grad}")
print(f"Gradient of y with respect to x2: {x2.grad}")
# Out:
# Gradient of y with respect to x1: 0.0
# Gradient of y with respect to x2: 0.002896492835134268

# %% [markdown]
# ![_cgi-bin_mmwebwx-bin_webwxgetmsgimg__&MsgID=5030567373224771402&skey=@crypt_11f830e3_c978d3def98fe9c3148bffee5e276dc1&mmweb_appid=wx_webfilehelper.jfif](attachment:f25beae7-819a-45cd-8a47-3bd046d19492.jfif)
